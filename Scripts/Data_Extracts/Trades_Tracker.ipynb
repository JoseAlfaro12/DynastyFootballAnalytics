# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_colwidth', None)

# %%
trades_2023 = pd.DataFrame([
    {
        'date': '08/29/2023',
        'receiving_owner': 'Jacky',
        'giving_owner': 'Marvin',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2', '2024_3'],
        'go_picks_received': ['2024_2', '2024_3'],
        'go_picks_gave': []
    },
    {
        'date': '08/29/2023',    
        'receiving_owner': 'Devonte',
        'giving_owner': 'Marvin',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2', '2025_3'],
        'go_picks_received': ['2024_2', '2025_3'],
        'go_picks_gave': []
    },
    {
        'date': '08/30/2023',        
        'receiving_owner': 'Daryl',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': ['2024_1'],
        'go_picks_received': ['2024_1'],
        'go_picks_gave': ['2024_3']
    },        
    {
        'date': '09/02/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2025_4'],
        'ro_picks_gave': ['2025_3'],
        'go_picks_received': ['2025_3'],
        'go_picks_gave': ['2025_4']
    },       
    {
        'date': '09/02/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Brigido',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': []
    },
        {
        'date': '09/03/2023',
        'receiving_owner': 'Luis',
        'giving_owner': 'Bryan',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_3'],
        'go_picks_received': ['2025_3'],
        'go_picks_gave': []
    },
        {
        'date': '09/06/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Daryl',
        'ro_picks_received': ['2024_4', '2025_1'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_4', '2025_1']
    },
        {
        'date': '09/06/2023',
        'receiving_owner': 'Devonte',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2024_1'],
        'ro_picks_gave': ['2024_4', '2025_2'],
        'go_picks_received': ['2024_4', '2025_2'],
        'go_picks_gave': ['2024_1']
    },
        {
        'date': '09/10/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Lalo',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_4'],
        'go_picks_received': ['2025_4'],
        'go_picks_gave': []
    },
        {
        'date': '09/12/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Bryan',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_4'],
        'go_picks_received': ['2025_4'],
        'go_picks_gave': []
    },
        {
        'date': '09/13/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2024_2', '2024_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2', '2024_3']
    },
        {
        'date': '09/13/2023',
        'receiving_owner': 'Marvin',
        'giving_owner': 'Jacky',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2'],
        'go_picks_received': ['2024_2'],
        'go_picks_gave': []
    },
        {
        'date': '09/16/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Brigido',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2'],
        'go_picks_received': ['2024_2'],
        'go_picks_gave': []
    },    
            {
        'date': '09/20/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2025_1', '2026_1'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_1', '2026_1']
    },    
            {
        'date': '09/20/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2024_1', '2025_1', '2026_1', '2024_1'],
        'ro_picks_gave': ['2025_2'],
        'go_picks_received': ['2025_2'],
        'go_picks_gave': ['2024_1', '2025_1', '2026_1', '2024_1']
    },    
            {
        'date': '09/20/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Marvin',
        'ro_picks_received': ['2024_2', '2024_1', '2025_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2', '2024_1', '2025_3']
    },    
            {
        'date': '09/20/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2024_2', '2024_4'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2', '2024_4']
    },    
            {
        'date': '09/22/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Marvin',
        'ro_picks_received': ['2024_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2']
    },    
            {
        'date': '09/22/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Daryl',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_1'],
        'go_picks_received': ['2025_1'],
        'go_picks_gave': []
    },    
            {
        'date': '09/22/2023',
        'receiving_owner': 'Luis',
        'giving_owner': 'Devonte',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2', '2025_1'],
        'go_picks_received': ['2024_2', '2025_1'],
        'go_picks_gave': []
    },    
            {
        'date': '09/22/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2024_1', '2025_1'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_1', '2025_1']
    },    
            {
        'date': '09/23/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Brigido',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3', '2024_2'],
        'go_picks_received': ['2024_3', '2024_2'],
        'go_picks_gave': []
    },    
            {
        'date': '09/26/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2024_2'],
        'ro_picks_gave': ['2024_1'],
        'go_picks_received': ['2024_1'],
        'go_picks_gave': ['2024_2']
    },    
            {
        'date': '09/26/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2024_1', '2025_2'],
        'ro_picks_gave': ['2024_4'],
        'go_picks_received': ['2024_4'],
        'go_picks_gave': ['2024_1', '2025_2']
    },    
            {
        'date': '09/28/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2025_4'],
        'ro_picks_gave': ['2025_2'],
        'go_picks_received': ['2025_2'],
        'go_picks_gave': ['2025_4']
    },    
            {
        'date': '09/30/2023',
        'receiving_owner': 'Marvin',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2025_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_2']
    },    
            {
        'date': '10/03/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': ['2024_2'],
        'go_picks_received': ['2024_2'],
        'go_picks_gave': ['2024_3']
    },    
            {
        'date': '10/03/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2024_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2']
    },    
            {
        'date': '10/06/2023',
        'receiving_owner': 'Marvin',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2024_1'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_1']
    },    
            {
        'date': '10/07/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Marvin',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_1'],
        'go_picks_received': ['2024_1'],
        'go_picks_gave': []
    },    
            {
        'date': '10/08/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2025_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_2']
    },    
            {
        'date': '10/10/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2025_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_3']
    },    
            {
        'date': '10/10/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Lalo',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2'],
        'go_picks_received': ['2024_2'],
        'go_picks_gave': []
    },    
            {
        'date': '10/12/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Luis',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_2', '2024_3'],
        'go_picks_received': ['2025_2', '2024_3'],
        'go_picks_gave': []
    },
                {
        'date': '10/12/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2025_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_2']
    },            {
        'date': '10/15/2023',
        'receiving_owner': 'Devonte',
        'giving_owner': 'Bryan',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': []
    },            {
        'date': '10/18/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2025_2', '2025_2', '2024_2'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_2', '2025_2', '2024_2']
    },            {
        'date': '10/19/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2024_1'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_1']
    },            {
        'date': '10/19/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Lalo',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3', '2025_1'],
        'go_picks_received': ['2024_3', '2025_1'],
        'go_picks_gave': []
    },            {
        'date': '10/20/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2025_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2025_3']
    },            {
        'date': '10/20/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_3']
    },            {
        'date': '10/21/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Brigido',
        'ro_picks_received': [],
        'ro_picks_gave': ['2025_1', '2024_1'],
        'go_picks_received': ['2025_1', '2024_1'],
        'go_picks_gave': []
    },            {
        'date': '10/24/2023',
        'receiving_owner': 'Luis',
        'giving_owner': 'Devonte',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_4'],
        'go_picks_received': ['2024_4'],
        'go_picks_gave': []
    },            {
        'date': '10/28/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2025_4', '2024_1'],
        'ro_picks_gave': ['2026_1', '2026_3', '2024_3'],
        'go_picks_received': ['2026_1', '2026_3', '2024_3'],
        'go_picks_gave': ['2025_4', '2024_1']
    },            {
        'date': '11/01/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Marvin',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': ['2024_1'],
        'go_picks_received': ['2024_1'],
        'go_picks_gave': ['2024_3']
    },            {
        'date': '11/01/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2025_1', '2024_2'],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': ['2025_1', '2024_2']
    },            {
        'date': '11/02/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Brigido',
        'ro_picks_received': ['2024_2', '2025_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_2', '2025_3']
    },            {
        'date': '11/03/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Devonte',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_2'],
        'go_picks_received': ['2024_2'],
        'go_picks_gave': []
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Luis',
        'giving_owner': 'Bryan',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_4'],
        'go_picks_received': ['2024_4'],
        'go_picks_gave': []
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2024_4', '2025_1'],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': ['2024_4', '2025_1']
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Lalo',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2024_4', '2026_3'],
        'ro_picks_gave': [],
        'go_picks_received': [],
        'go_picks_gave': ['2024_4', '2026_3']
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Marvin',
        'ro_picks_received': [],
        'ro_picks_gave': ['2026_4'],
        'go_picks_received': ['2026_4'],
        'go_picks_gave': []
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Lalo',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': []
    },            {
        'date': '11/07/2023',
        'receiving_owner': 'Luis',
        'giving_owner': 'Lalo',
        'ro_picks_received': [],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': []
    },            {
        'date': '11/08/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2026_4'],
        'ro_picks_gave': ['2026_3'],
        'go_picks_received': ['2026_3'],
        'go_picks_gave': ['2026_4']
    },
        {
        'date': '11/11/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_3']
    },
            {
        'date': '11/12/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Brigido',
        'ro_picks_received': ['2025_1', '2025_1', '2024_4', '2024_1', '2024_2'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2025_1', '2025_1', '2024_4', '2024_1', '2024_2']
    },        {
        'date': '11/12/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Jacky',
        'ro_picks_received': ['2024_1'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_1']
    },        {
        'date': '11/14/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Marvin',
        'ro_picks_received': ['2024_1'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_1']
    },        {
        'date': '11/15/2023',
        'receiving_owner': 'Devonte',
        'giving_owner': 'Marvin',
        'ro_picks_received': ['2024_1', '2025_2'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_1', '2025_2']
    },        {
        'date': '11/19/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2025_1'],
        'ro_picks_gave': ['2024_4', '2026_2', '2025_4'],
        'go_picks_received': ['2024_4', '2026_2', '2025_4'],
        'go_picks_gave': ['2025_1']
    },        {
        'date': '11/21/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Brigido',
        'ro_picks_received': ['2024_1', '2025_2', '2026_1'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_1', '2025_2', '2026_1']
    },        {
        'date': '11/21/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2024_4'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_4']
    },        {
        'date': '11/21/2023',
        'receiving_owner': 'Weeks',
        'giving_owner': 'Marvin',
        'ro_picks_received': [''],
        'ro_picks_gave': ['2024_3'],
        'go_picks_received': ['2024_3'],
        'go_picks_gave': ['']
    },        {
        'date': '11/22/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Devonte',
        'ro_picks_received': ['2024_3'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2024_3']
    },
      {
        'date': '11/26/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Bryan',
        'ro_picks_received': ['2025_2'],
        'ro_picks_gave': ['2025_2', '2024_4'],
        'go_picks_received': ['2025_2', '2024_4'],
        'go_picks_gave': ['2025_2']
    },  {
        'date': '11/27/2023',
        'receiving_owner': 'Brigido',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2025_2'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2025_2']
    },  {
        'date': '11/28/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Luis',
        'ro_picks_received': ['2026_4'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2026_4']
    },  {
        'date': '11/28/2023',
        'receiving_owner': 'Jose',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2026_4'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2026_4']
    },  {
        'date': '11/29/2023',
        'receiving_owner': 'Daryl',
        'giving_owner': 'Weeks',
        'ro_picks_received': ['2025_1', '2025_1', '2025_3', '2024_4', '2024_1', '2024_2'],
        'ro_picks_gave': [''],
        'go_picks_received': [''],
        'go_picks_gave': ['2025_1', '2025_1', '2025_3', '2024_4', '2024_1', '2024_2']
    }

])

# %%
trades_2023
# Out:
#           date receiving_owner giving_owner  \
# 0   08/29/2023           Jacky       Marvin
# 1   08/29/2023         Devonte       Marvin
# 2   08/30/2023           Daryl        Bryan
# 3   09/02/2023           Daryl         Luis
# 4   09/02/2023           Daryl      Brigido
# ..         ...             ...          ...
# 65  11/26/2023            Jose        Bryan
# 66  11/27/2023         Brigido         Luis
# 67  11/28/2023            Jose         Luis
# 68  11/28/2023            Jose        Weeks
# 69  11/29/2023           Daryl        Weeks
#
#                                    ro_picks_received     ro_picks_gave  \
# 0                                                 []  [2024_2, 2024_3]
# 1                                                 []  [2024_2, 2025_3]
# 2                                           [2024_3]          [2024_1]
# 3                                           [2025_4]          [2025_3]
# 4                                                 []          [2024_3]
# ...

# %%
# # Ensure date column is datetime
# trades_2023['date'] = pd.to_datetime(trades_2023['date'], format='%m/%d/%Y')

# %%
# week_starts_2023 = [
#     (1,  '2023-09-07'),
#     (2,  '2023-09-14'),
#     (3,  '2023-09-21'),
#     (4,  '2023-09-28'),
#     (5,  '2023-10-05'),
#     (6,  '2023-10-12'),
#     (7,  '2023-10-19'),
#     (8,  '2023-10-26'),
#     (9,  '2023-11-02'),
#     (10, '2023-11-09'),
#     (11, '2023-11-16'),
#     (12, '2023-11-23'),
#     (13, '2023-11-30'),
#     (14, '2023-12-07')
# ]

# week_starts_2024 = [
#     (1,  '2024-09-05'),
#     (2,  '2024-09-12'),
#     (3,  '2024-09-19'),
#     (4,  '2024-09-26'),
#     (5,  '2024-10-03'),
#     (6,  '2024-10-10'),
#     (7,  '2024-10-17'),
#     (8,  '2024-10-24'),
#     (9,  '2024-10-31'),
#     (10, '2024-11-07'),
#     (11, '2024-11-14'),
#     (12, '2024-11-21'),
#     (13, '2024-11-28'),
#     (14, '2024-12-05')
# ]

# week_starts_2025 = [
#     (1,  '2024-09-04'),
#     (2,  '2024-09-10'),
#     (3,  '2024-09-17'),
#     (4,  '2024-09-24'),
#     (5,  '2024-10-01'),
#     (6,  '2024-10-08'),
#     (7,  '2024-10-15'),
#     (8,  '2024-10-22'),
#     (9,  '2024-10-29'),
#     (10, '2024-11-05'),
#     (11, '2024-11-12'),
#     (12, '2024-11-19'),
#     (13, '2024-11-26'),
#     (14, '2024-12-03')
# ]

# week_starts = [(wk, pd.to_datetime(dt)) for wk, dt in week_starts]

# %%
# def classify_week(trade_date):
#     trade_date = pd.to_datetime(trade_date)

#     # Pre-season: before first regular-season game
#     if trade_date < week_starts[0][1]:
#         return 'pre-season'

#     # In-season: assign to the *latest* week whose start date has passed
#     for i in range(len(week_starts) - 1):
#         current_week, current_start = week_starts[i]
#         next_week, next_start = week_starts[i + 1]

#         if current_start <= trade_date < next_start:
#             return f'{current_week + 1}' if trade_date > current_start else f'{current_week}'

#     # After Week 14 start
#     if trade_date >= week_starts[-1][1]:
#         # Trades after Week 14 games end → offseason
#         if trade_date > pd.to_datetime('2023-12-11'):
#             return 'offseason'
#         return 'Week 14'

# %%
# trades_2023['week'] = trades_2023['date'].apply(classify_week)

# %% [markdown]
# ## Analysis

# %%
# Get all unique owners
all_owners = pd.concat([trades_2023['receiving_owner'], trades_2023['giving_owner']])
owners = all_owners.unique()

# Initialize pick ownership dictionary
starting_picks = {}
for owner in owners:
    starting_picks[owner] = [
        '2024_1','2024_2','2024_3','2024_4',
        '2025_1','2025_2','2025_3','2025_4',
        '2026_1','2026_2','2026_3','2026_4'
    ]

# %%
starting_picks
# Out:
# {'Jacky': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4'],
#  'Devonte': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4'],
#  'Daryl': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4'],
#  'Luis': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4'],
#  'Jose': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4'],
#  'Lalo': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_2',
#   '2025_3',
# ...

# %%
# Process trades
for _, trade in trades_2023.iterrows():
    # Receiving owner: add received, remove gave
    starting_picks[trade['receiving_owner']].extend(trade['ro_picks_received'])
    for pick in trade['ro_picks_gave']:
        if pick in starting_picks[trade['receiving_owner']]:
            starting_picks[trade['receiving_owner']].remove(pick)
    
    # Giving owner: add received, remove gave
    starting_picks[trade['giving_owner']].extend(trade['go_picks_received'])
    for pick in trade['go_picks_gave']:
        if pick in starting_picks[trade['giving_owner']]:
            starting_picks[trade['giving_owner']].remove(pick)

# %%
starting_picks
# Out:
# {'Jacky': ['2025_4', '2026_2', '2026_4', '2024_4', ''],
#  'Devonte': ['2025_4',
#   '2026_2',
#   '2026_3',
#   '2026_4',
#   '2024_2',
#   '2024_1',
#   '2025_2',
#   ''],
#  'Daryl': ['2025_1',
#   '2025_4',
#   '2025_1',
#   '2025_1',
#   '2025_1',
#   '2025_1',
#   '2025_3',
#   '2024_4',
#   '2024_1',
#   '2024_2'],
#  'Luis': ['2026_1', '2026_2', '2026_3', '', '', ''],
#  'Jose': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2025_3',
#   '2025_4',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4',
#   '2024_4',
#   '2025_1',
#   '2024_2',
#   '2024_4',
#   '2024_2',
#   '2025_3',
#   '2025_2',
#   '2025_2',
#   '2024_2',
#   '2024_2',
#   '2025_3',
#   '2024_1',
#   '2025_2',
#   '2026_1',
#   '2024_4',
#   '2025_2',
#   '2026_4',
#   '2026_4'],
#  'Lalo': ['2024_1',
#   '2024_2',
#   '2024_3',
#   '2024_4',
#   '2025_1',
#   '2025_3',
#   '2026_1',
#   '2026_2',
#   '2026_3',
#   '2026_4',
#   '2025_4',
#   '2025_1',
#   '2026_1',
#   '2024_1',
#   '2025_1',
#   '2026_1',
# ...

# %%
# Create a summary DataFrame
final_picks = pd.DataFrame([
    {'owner': owner, 'final_picks': picks, 'num_picks': len(picks)}
    for owner, picks in starting_picks.items()
])

# %%
final_picks
# Out:
#      owner  \
# 0    Jacky
# 1  Devonte
# 2    Daryl
# 3     Luis
# 4     Jose
# 5     Lalo
# 6   Marvin
# 7    Weeks
# 8  Brigido
# 9    Bryan
#
#                                                                                                                                                                                                                         final_picks  \
# 0                                                                                                                                                                                                [2025_4, 2026_2, 2026_4, 2024_4, ]
# 1                                                                                                                                                                        [2025_4, 2026_2, 2026_3, 2026_4, 2024_2, 2024_1, 2025_2, ]
# ...

# %%
# Function to sort picks
def sort_picks(picks):
    # Filter out any empty strings
    picks = [p for p in picks if p]
    # Sort by season then round
    picks_sorted = sorted(
        picks,
        key=lambda x: (int(x.split('_')[0]), int(x.split('_')[1]))
    )
    return picks_sorted

# Apply to the final_picks column
final_picks['final_picks'] = final_picks['final_picks'].apply(sort_picks)

# Display the result
final_picks[['owner','final_picks', 'num_picks']].sort_values('num_picks', ascending= False)
# Out:
#      owner  \
# 5     Lalo
# 4     Jose
# 9    Bryan
# 6   Marvin
# 7    Weeks
# 2    Daryl
# 1  Devonte
# 3     Luis
# 8  Brigido
# 0    Jacky
#
#                                                                                                                                                                                                                         final_picks  \
# 5  [2024_1, 2024_1, 2024_1, 2024_1, 2024_2, 2024_2, 2024_2, 2024_3, 2024_3, 2024_3, 2024_3, 2024_4, 2024_4, 2025_1, 2025_1, 2025_1, 2025_1, 2025_3, 2025_3, 2025_3, 2025_4, 2026_1, 2026_1, 2026_1, 2026_2, 2026_3, 2026_3, 2026_4]
# 4          [2024_1, 2024_1, 2024_2, 2024_2, 2024_2, 2024_2, 2024_2, 2024_3, 2024_4, 2024_4, 2024_4, 2025_1, 2025_2, 2025_2, 2025_2, 2025_2, 2025_3, 2025_3, 2025_3, 2025_4, 2026_1, 2026_1, 2026_2, 2026_3, 2026_4, 2026_4, 2026_4]
# ...

# %%
import pandas as pd

# Combine receiving_owner and giving_owner into a single Series
all_owners = pd.concat([trades_2023['receiving_owner'], trades_2023['giving_owner']])

# Count occurrences of each owner
trade_counts = all_owners.value_counts().sort_values(ascending=False)

# Convert to DataFrame
trade_counts_df = trade_counts.reset_index()
trade_counts_df.columns = ['owner', 'trade_count']

# Add percentage column
trade_counts_df['trade_pct'] = (trade_counts_df['trade_count'] / trade_counts_df['trade_count'].sum() * 100).round(2)

print(trade_counts_df)
# Out:
#      owner  trade_count  trade_pct
# 0    Daryl           21      15.00
# 1  Brigido           17      12.14
# 2    Weeks           16      11.43
# 3     Luis           14      10.00
# 4  Devonte           13       9.29
# 5   Marvin           13       9.29
# 6    Bryan           13       9.29
# 7     Jose           12       8.57
# 8     Lalo           11       7.86
# 9    Jacky           10       7.14

# %% [markdown]
# ### 2024

# %%
trades_2024 = pd.DataFrame([
    {
        "date": "03/04/2024",
        "receiving_owner": "Jose",
        "giving_owner": "Devonte",
        "ro_picks_received": ["2024_2", "2024_1", "2025_2"],
        "ro_picks_gave": ["2024_2"],
        "go_picks_received": ["2024_2"],
        "go_picks_gave": ["2024_2", "2024_1", "2025_2"],
    },
    {
        "date": '03/05/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2024_3'],
        "ro_picks_gave": ['2025_1', '2025_3', '2024_1', '2024_2'],
        "go_picks_received": ['2025_1', '2025_3', '2024_1', '2024_2'],
        "go_picks_gave": ['2024_3'],
    },
        {
        "date": '03/19/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2024_4'],
        "ro_picks_gave": ['2024_3'],
        "go_picks_received": ['2024_3'],
        "go_picks_gave": ['2024_4'],
    },    {
        "date": '04/06/2024',
        "receiving_owner": 'Luis',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2026_2'],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": ['2026_2'],
    },    {
        "date": '04/07/2024',
        "receiving_owner": 'Jose',
        "giving_owner": 'Brigido',
        "ro_picks_received": ['2024_3'],
        "ro_picks_gave": ['2024_4', '2024_4'],
        "go_picks_received": ['2024_4', '2024_4'],
        "go_picks_gave": ['2024_3'],
    },    {
        "date": '04/15/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": [],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": [''],
    },    {
        "date": '04/17/2025',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Gio',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2024_4'],
        "go_picks_received": ['2024_4'],
        "go_picks_gave": [''],
    },    {
        "date": '04/20/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Jacky',
        "ro_picks_received": ['2025_4'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2025_4'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Gio',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": [''],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Jacky',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2024_2'],
        "ro_picks_gave": ['2026_2', '2026_4'],
        "go_picks_received": ['2026_2', '2026_4'],
        "go_picks_gave": ['2024_2'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Gio',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2024_4'],
        "go_picks_received": ['2024_4'],
        "go_picks_gave": [''],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Devonte',
        "giving_owner": 'Jacky',
        "ro_picks_received": ['2024_2'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2024_2'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Lalo',
        "ro_picks_received": ['2024_3', '2024_2', '2024_1'],
        "ro_picks_gave": ['2024_1'],
        "go_picks_received": ['2024_1'],
        "go_picks_gave": ['2024_3', '2024_2', '2024_1'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Jose',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2024_1'],
        "ro_picks_gave": ['2024_1', '2024_2'],
        "go_picks_received": ['2024_1', '2024_2'],
        "go_picks_gave": ['2024_1'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Luis',
        "giving_owner": 'Lalo',
        "ro_picks_received": ['2024_3', '2024_2', '2024_4'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2024_3', '2024_2', '2024_4'],
    },    {
        "date": '04/28/2024',
        "receiving_owner": 'Lalo',
        "giving_owner": 'Devonte',
        "ro_picks_received": ['2026_2'],
        "ro_picks_gave": ['2024_3'],
        "go_picks_received": ['2024_3'],
        "go_picks_gave": ['2026_2'],
    },    {
        "date": '04/29/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Luis',
        "ro_picks_received": ['2024_4'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2024_4'],
    },    {
        "date": '04/29/2024',
        "receiving_owner": 'Jacky',
        "giving_owner": 'Bryan',
        "ro_picks_received": [],
        "ro_picks_gave": ['2024_4'],
        "go_picks_received": ['2024_4'],
        "go_picks_gave": [''],
    },    {
        "date": '04/29/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2024_4'],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": ['2024_4'],
    },    {
        "date": '05/02/2024',
        "receiving_owner": 'Luis',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2026_1'],
        "ro_picks_gave": ['2026_1', '2026_3'],
        "go_picks_received": ['2026_1', '2026_3'],
        "go_picks_gave": ['2026_1'],
    },    {
        "date": '05/03/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2027_4'],
        "go_picks_received": ['2027_4'],
        "go_picks_gave": [''],
    },    {
        "date": '05/03/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Brigido',
        "ro_picks_received": ['2025_2', '2026_2'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2025_2', '2026_2'],
    },    {
        "date": '05/12/2024',
        "receiving_owner": 'Jose',
        "giving_owner": 'Marvin',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_2'],
        "go_picks_received": ['2025_2'],
        "go_picks_gave": [''],
    },    {
        "date": '05/28/2024',
        "receiving_owner": 'Jose',
        "giving_owner": 'Devonte',
        "ro_picks_received": ['2025_4'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2025_4'],
    },    {
        "date": '05/30/2024',
        "receiving_owner": 'Brigido',
        "giving_owner": 'Devonte',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_4'],
        "go_picks_received": ['2026_4'],
        "go_picks_gave": [''],
    },    {
        "date": '05/31/2024',
        "receiving_owner": 'Brigido',
        "giving_owner": 'Devonte',
        "ro_picks_received": ['2026_3'],
        "ro_picks_gave": ['2026_4'],
        "go_picks_received": ['2026_4'],
        "go_picks_gave": ['2026_3'],
    },    {
        "date": '06/14/2024',
        "receiving_owner": 'Luis',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2027_1'],
        "ro_picks_gave": ['2027_1', '2027_4'],
        "go_picks_received": ['2027_1', '2027_4'],
        "go_picks_gave": ['2027_1'],
    },    {
        "date": '06/19/2024',
        "receiving_owner": 'Luis',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2025_4'],
        "ro_picks_gave": ['2027_2', '2027_3'],
        "go_picks_received": ['2027_2', '2027_3'],
        "go_picks_gave": ['2025_4'],
    },    {
        "date": '07/06/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2025_3', '2025_3'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2025_3', '2025_3'],
    },    {
        "date": '07/06/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Devonte',
        "ro_picks_received": ['2026_4'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2026_4'],
    },    {
        "date": '07/23/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2027_2', '2027_3'],
        "ro_picks_gave": ['2027_2', '2027_3'],
        "go_picks_received": ['2027_2', '2027_3'],
        "go_picks_gave": ['2027_2', '2027_3'],
    },    {
        "date": '08/03/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2026_3', '2026_3'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2026_3', '2026_3'],
    },    {
        "date": '09/10/2024',
        "receiving_owner": 'Brigido',
        "giving_owner": 'Devonte',
        "ro_picks_received": [],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": [''],
    },    {
        "date": '09/18/2024',
        "receiving_owner": 'Marvin',
        "giving_owner": 'Jacky',
        "ro_picks_received": [],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": [],
    },    {
        "date": '10/01/2024',
        "receiving_owner": 'Devonte',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2027_4', '2027_3', '2025_2'],
        "ro_picks_gave": ['2025_4', '2026_4', '2027_1', '2027_2'],
        "go_picks_received": ['2025_4', '2026_4', '2027_1', '2027_2'],
        "go_picks_gave": ['2027_4', '2027_3', '2025_2'],
    },    {
        "date": '10/04/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2026_2', '2025_2'],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": ['2026_2', '2025_2'],
    },    {
        "date": '10/11/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Luis',
        "ro_picks_received": ['2025_4'],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": ['2025_4'],
    },    {
        "date": '10/14/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Gio',
        "ro_picks_received": [],
        "ro_picks_gave": ['2025_4', '2027_3'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": [''],
    },    {
        "date": '10/14/2025',
        "receiving_owner": 'Bryan',
        "giving_owner": 'Daryl',
        "ro_picks_received": ['2027_3'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": [''],
    },    {
        "date": '10/30/2024',
        "receiving_owner": 'Brigido',
        "giving_owner": 'Lalo',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_3'],
        "go_picks_received": ['2026_3'],
        "go_picks_gave": [''],
    },    {
        "date": '11/07/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Brigido',
        "ro_picks_received": ['2027_2', '2027_4'],
        "ro_picks_gave": ['2027_1'],
        "go_picks_received": ['2027_1'],
        "go_picks_gave": ['2027_2', '2027_4'],
    },    {
        "date": '11/18/2024',
        "receiving_owner": 'Jacky',
        "giving_owner": 'Bryan',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_4', '2027_2'],
        "go_picks_received": ['2025_4', '2027_2'],
        "go_picks_gave": [''],
    },    {
        "date": '11/19/2024',
        "receiving_owner": 'Daryl',
        "giving_owner": 'Bryan',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2027_2', '2027_2'],
        "go_picks_received": ['2027_2', '2027_2'],
        "go_picks_gave": [''],
    },    {
        "date": '11/19/2024',
        "receiving_owner": 'Jose',
        "giving_owner": 'Bryan',
        "ro_picks_received": ['2027_4', '2023_3'],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": ['2027_4', '2023_3'],
    },    {
        "date": '11/20/2024',
        "receiving_owner": 'Brigido',
        "giving_owner": 'Lalo',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2027_1', '2027_3'],
        "go_picks_received": ['2027_1', '2027_3'],
        "go_picks_gave": [''],
    },    {
        "date": '11/20/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Bryan',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": ['2025_4'],
        "go_picks_gave": [''],
    },    {
        "date": '11/23/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Brigido',
        "ro_picks_received": ['2027_1'],
        "ro_picks_gave": [],
        "go_picks_received": [],
        "go_picks_gave": ['2027_1'],
    },    {
        "date": '11/25/2024',
        "receiving_owner": 'Gio',
        "giving_owner": 'Brigido',
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": [''],
    }
])

# %%
trades_2024
# Out:
#           date receiving_owner giving_owner         ro_picks_received  \
# 0   03/04/2024            Jose      Devonte  [2024_2, 2024_1, 2025_2]
# 1   03/05/2024           Daryl        Bryan                  [2024_3]
# 2   03/19/2024           Daryl        Bryan                  [2024_4]
# 3   04/06/2024            Luis        Bryan                  [2026_2]
# 4   04/07/2024            Jose      Brigido                  [2024_3]
# 5   04/15/2024           Daryl        Bryan                        []
# 6   04/17/2025           Daryl          Gio                        []
# 7   04/20/2024             Gio        Jacky                  [2025_4]
# 8   04/28/2024           Daryl          Gio                        []
# 9   04/28/2024           Jacky        Bryan                  [2024_2]
# 10  04/28/2024           Daryl          Gio                        []
# 11  04/28/2024         Devonte        Jacky                  [2024_2]
# ...

# %%
import pandas as pd

# Combine receiving_owner and giving_owner into a single Series
all_owners = pd.concat([trades_2024['receiving_owner'], trades_2024['giving_owner']])

# Count occurrences of each owner
trade_counts = all_owners.value_counts().sort_values(ascending=False)

# Convert to DataFrame
trade_counts_df = trade_counts.reset_index()
trade_counts_df.columns = ['owner', 'trade_count']

# Add percentage column
trade_counts_df['trade_pct'] = (trade_counts_df['trade_count'] / trade_counts_df['trade_count'].sum() * 100).round(2)

print(trade_counts_df)
# Out:
#      owner  trade_count  trade_pct
# 0    Bryan           22      22.92
# 1    Daryl           15      15.62
# 2      Gio           14      14.58
# 3  Brigido           10      10.42
# 4  Devonte            9       9.38
# 5     Luis            7       7.29
# 6     Jose            6       6.25
# 7    Jacky            6       6.25
# 8     Lalo            5       5.21
# 9   Marvin            2       2.08

# %% [markdown]
# ### 2025 Trades

# %%
trades_2025 = pd.DataFrame([
    {
        "date": "01/14/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2027_2', '2027_1', '2026_2'],
        "ro_picks_gave": ['2025_4', '2027_1', '2025_4'],
        "go_picks_received": ['2025_4', '2027_1', '2025_4'],
        "go_picks_gave": ['2027_2', '2027_1', '2026_2'],
    },    {
        "date": "02/01/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Devonte",
        "ro_picks_received": ['2025_2'],
        "ro_picks_gave": ['2025_3'],
        "go_picks_received": ['2025_3'],
        "go_picks_gave": ['2025_2'],
    },   {
        "date": "02/02/2025",
        "receiving_owner": "Devonte",
        "giving_owner": "Marvin",
        "ro_picks_received": ['2025_2'],
        "ro_picks_gave": ['2025_3'],
        "go_picks_received": ['2025_3'],
        "go_picks_gave": ['2025_2'],
    },   {
        "date": "02/02/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Luis",
        "ro_picks_received": ['2027_1'],
        "ro_picks_gave": ['2025_2'],
        "go_picks_received": ['2025_2'],
        "go_picks_gave": ['2027_1'],
    },   {
        "date": "02/02/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Luis",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": [''],
    },   {
        "date": "02/07/2025",
        "receiving_owner": "Devonte",
        "giving_owner": "Bryan",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2027_3', '2027_3'],
        "go_picks_received": ['2027_3', '2027_3'],
        "go_picks_gave": [''],
    },   {
        "date": "02/09/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Luis",
        "ro_picks_received": ['2025_2'],
        "ro_picks_gave": ['2025_3'],
        "go_picks_received": ['2025_3'],
        "go_picks_gave": ['2025_2'],
    },   {
        "date": "02/15/2025",
        "receiving_owner": "Devonte",
        "giving_owner": "Jacky",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_2'],
        "go_picks_received": ['2025_2'],
        "go_picks_gave": [''],
    },   {
        "date": "02/17/2025",
        "receiving_owner": "Daryl",
        "giving_owner": "Luis",
        "ro_picks_received": ['2026_2'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2026_2'],
    },   {
        "date": "03/12/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Lalo",
        "ro_picks_received": ['2025_1', '2025_1', '2026_2'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2025_1', '2025_1', '2026_2'],
    },   {
        "date": "03/20/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Brigido",
        "ro_picks_received": [],
        "ro_picks_gave": ['2025_2', '2026_1', '2026_3'],
        "go_picks_received": ['2025_2', '2026_1', '2026_3'],
        "go_picks_gave": [''],
    },   {
        "date": "03/31/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Marvin",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": [''],
    },   {
        "date": "03/31/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Devonte",
        "ro_picks_received": ['2026_4'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2026_4'],
    },   {
        "date": "04/02/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Gio",
        "ro_picks_received": ['2027_1'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2027_1'],
    },   {
        "date": "04/15/2025",
        "receiving_owner": "Daryl",
        "giving_owner": "Gio",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2027_4'],
        "go_picks_received": ['2027_4'],
        "go_picks_gave": [''],
    },   {
        "date": "04/26/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2025_4'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2025_4'],
    },   {
        "date": "04/28/2025",
        "receiving_owner": "Marvin",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2025_4', '2025_1'],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": ['2025_4', '2025_1'],
    },   {
        "date": "04/28/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Marvin",
        "ro_picks_received": ['2025_1', '2025_2'],
        "ro_picks_gave": ['2025_1'],
        "go_picks_received": ['2025_1'],
        "go_picks_gave": ['2025_1', '2025_2'],
    },   {
        "date": "04/28/2025",
        "receiving_owner": "Marvin",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2026_1', '2026_3', '2025_1'],
        "ro_picks_gave": ['2025_1', '2026_1', '2026_2'],
        "go_picks_received": ['2025_1', '2026_1', '2026_2'],
        "go_picks_gave": ['2026_1', '2026_3', '2025_1'],
    },   {
        "date": "04/29/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Jacky",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2025_4'],
        "go_picks_received": [''],
        "go_picks_gave": ['2025_4'],
    },   {
        "date": "04/29/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Marvin",
        "ro_picks_received": ['2025_1'],
        "ro_picks_gave": ['2025_2', '2026_1'],
        "go_picks_received": ['2025_2', '2026_1'],
        "go_picks_gave": ['2025_1'],
    },   {
        "date": "04/29/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Luis",
        "ro_picks_received": ['2025_3', '2025_1'],
        "ro_picks_gave": ['2025_2', '2025_3', '2025_2'],
        "go_picks_received": ['2025_2', '2025_3', '2025_2'],
        "go_picks_gave": ['2025_3', '2025_1'],
    },   {
        "date": "04/30/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Gio",
        "ro_picks_received": ['2025_2', '2025_2'],
        "ro_picks_gave": ['2025_3', '2025_2'],
        "go_picks_received": ['2025_3', '2025_2'],
        "go_picks_gave": ['2025_2', '2025_2'],
    },   {
        "date": "04/30/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Lalo",
        "ro_picks_received": ['2025_3', '2025_3'],
        "ro_picks_gave": ['2025_2'],
        "go_picks_received": ['2025_2'],
        "go_picks_gave": ['2025_3', '2025_3'],
    },   {
        "date": "04/30/2025",
        "receiving_owner": "Daryl",
        "giving_owner": "Gio",
        "ro_picks_received": ['2025_3'],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": ['2025_3'],
    },   {
        "date": "05/01/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Lalo",
        "ro_picks_received": ['2026_4', '2025_3'],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": ['2026_4', '2025_3'],
    },   {
        "date": "05/06/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Brigido",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_4'],
        "go_picks_received": ['2026_4'],
        "go_picks_gave": [''],
    },   {
        "date": "08/12/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Bryan",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_3'],
        "go_picks_received": ['2026_3'],
        "go_picks_gave": [''],
    },   {
        "date": "09/23/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Luis",
        "ro_picks_received": ['2026_3'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2026_3'],
    },   {
        "date": "10/21/2025",
        "receiving_owner": "Luis",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2027_2'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2027_2'],
    },   {
        "date": "11/01/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Brigido",
        "ro_picks_received": ['2026_4'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2026_4'],
    },   {
        "date": "11/08/2025",
        "receiving_owner": "Brigido",
        "giving_owner": "Luis",
        "ro_picks_received": [''],
        "ro_picks_gave": ['2026_2'],
        "go_picks_received": ['2026_2'],
        "go_picks_gave": [''],
    },   {
        "date": "11/20/2025",
        "receiving_owner": "Gio",
        "giving_owner": "Jacky",
        "ro_picks_received": ['2027_3'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2027_3'],
    }
    #### Manual Adjustment
    ,   {
        "date": "11/20/2025",
        "receiving_owner": "Jose",
        "giving_owner": "Bryan",
        "ro_picks_received": ['2026_3'],
        "ro_picks_gave": [''],
        "go_picks_received": [''],
        "go_picks_gave": ['2026_3', '2026_3'],
    }

])

# %%
trades_2025
# Out:
#           date receiving_owner giving_owner         ro_picks_received  \
# 0   01/14/2025             Gio        Bryan  [2027_2, 2027_1, 2026_2]
# 1   02/01/2025            Jose      Devonte                  [2025_2]
# 2   02/02/2025         Devonte       Marvin                  [2025_2]
# 3   02/02/2025            Jose         Luis                  [2027_1]
# 4   02/02/2025             Gio         Luis                        []
# 5   02/07/2025         Devonte        Bryan                        []
# 6   02/09/2025            Jose         Luis                  [2025_2]
# 7   02/15/2025         Devonte        Jacky                        []
# 8   02/17/2025           Daryl         Luis                  [2026_2]
# 9   03/12/2025         Brigido         Lalo  [2025_1, 2025_1, 2026_2]
# 10  03/20/2025             Gio      Brigido                        []
# 11  03/31/2025         Brigido       Marvin                        []
# ...

# %%
# Combine receiving_owner and giving_owner into a single Series
all_owners = pd.concat([trades_2025['receiving_owner'], trades_2025['giving_owner']])

# Count occurrences of each owner
trade_counts = all_owners.value_counts().sort_values(ascending=False)

# Convert to DataFrame
trade_counts_df = trade_counts.reset_index()
trade_counts_df.columns = ['owner', 'trade_count']

# Add percentage column
trade_counts_df['trade_pct'] = (trade_counts_df['trade_count'] / trade_counts_df['trade_count'].sum() * 100).round(2)

print(trade_counts_df)
# Out:
#      owner  trade_count  trade_pct
# 0      Gio           15      22.06
# 1  Brigido            9      13.24
# 2     Jose            8      11.76
# 3     Luis            8      11.76
# 4    Bryan            8      11.76
# 5   Marvin            6       8.82
# 6  Devonte            5       7.35
# 7    Daryl            3       4.41
# 8    Jacky            3       4.41
# 9     Lalo            3       4.41

# %% [markdown]
# ### Combine Datasets (2023-2025)

# %%
common_cols = [
    'date',
    'receiving_owner',
    'giving_owner',
    'ro_picks_received',
    'ro_picks_gave',
    'go_picks_received',
    'go_picks_gave'
]

trades_2023 = trades_2023[common_cols]
trades_2024 = trades_2024[common_cols]
trades_2025 = trades_2025[common_cols]

# %%
trades_2023 = trades_2023.assign(season=2023)
trades_2024 = trades_2024.assign(season=2024)
trades_2025 = trades_2025.assign(season=2025)

# %%
all_trades = pd.concat(
    [trades_2023, trades_2024, trades_2025],
    ignore_index=True
)

# %%
all_trades['date'] = pd.to_datetime(all_trades['date'], errors='coerce')
all_trades = all_trades.sort_values('date').reset_index(drop=True)

# %%
all_trades.head()
# Out:
#         date receiving_owner giving_owner ro_picks_received     ro_picks_gave  \
# 0 2023-08-29           Jacky       Marvin                []  [2024_2, 2024_3]
# 1 2023-08-29         Devonte       Marvin                []  [2024_2, 2025_3]
# 2 2023-08-30           Daryl        Bryan          [2024_3]          [2024_1]
# 3 2023-09-02           Daryl         Luis          [2025_4]          [2025_3]
# 4 2023-09-02           Daryl      Brigido                []          [2024_3]
#
#   go_picks_received go_picks_gave  season
# 0  [2024_2, 2024_3]            []    2023
# 1  [2024_2, 2025_3]            []    2023
# 2          [2024_1]      [2024_3]    2023
# 3          [2025_3]      [2025_4]    2023
# 4          [2024_3]            []    2023

# %%
all_trades.tail()
# Out:
#           date receiving_owner giving_owner ro_picks_received ro_picks_gave  \
# 147 2025-10-21            Luis        Bryan          [2027_2]            []
# 148 2025-11-01             Gio      Brigido          [2026_4]            []
# 149 2025-11-08         Brigido         Luis                []      [2026_2]
# 150 2025-11-20             Gio        Jacky          [2027_3]            []
# 151 2025-11-20            Jose        Bryan          [2026_3]            []
#
#     go_picks_received     go_picks_gave  season
# 147                []          [2027_2]    2025
# 148                []          [2026_4]    2025
# 149          [2026_2]                []    2025
# 150                []          [2027_3]    2025
# 151                []  [2026_3, 2026_3]    2025

# %% [markdown]
# ### Adding Season Week #

# %%
import pandas as pd

# Convert date column to datetime
all_trades['date'] = pd.to_datetime(all_trades['date'])

# Define week starts for each season
WEEK_STARTS = {
    2023: [
        (1,  '2023-09-07'),
        (2,  '2023-09-14'),
        (3,  '2023-09-21'),
        (4,  '2023-09-28'),
        (5,  '2023-10-05'),
        (6,  '2023-10-12'),
        (7,  '2023-10-19'),
        (8,  '2023-10-26'),
        (9,  '2023-11-02'),
        (10, '2023-11-09'),
        (11, '2023-11-16'),
        (12, '2023-11-23'),
        (13, '2023-11-30'),
        (14, '2023-12-07')
    ],
    2024: [
        (1,  '2024-09-05'),
        (2,  '2024-09-12'),
        (3,  '2024-09-19'),
        (4,  '2024-09-26'),
        (5,  '2024-10-03'),
        (6,  '2024-10-10'),
        (7,  '2024-10-17'),
        (8,  '2024-10-24'),
        (9,  '2024-10-31'),
        (10, '2024-11-07'),
        (11, '2024-11-14'),
        (12, '2024-11-21'),
        (13, '2024-11-28'),
        (14, '2024-12-05')
    ],
    2025: [
        (1,  '2025-09-04'),
        (2,  '2025-09-10'),
        (3,  '2025-09-17'),
        (4,  '2025-09-24'),
        (5,  '2025-10-01'),
        (6,  '2025-10-08'),
        (7,  '2025-10-15'),
        (8,  '2025-10-22'),
        (9,  '2025-10-29'),
        (10, '2025-11-05'),
        (11, '2025-11-12'),
        (12, '2025-11-19'),
        (13, '2025-11-26'),
        (14, '2025-12-03')
    ]
}

# Convert all week start strings to datetime
for season, weeks in WEEK_STARTS.items():
    WEEK_STARTS[season] = [(wk, pd.to_datetime(dt)) for wk, dt in weeks]

# Function to classify week
def classify_week(row):
    season = row['season']
    trade_date = row['date']
    
    week_starts = WEEK_STARTS[season]

    # Pre-season: before first week
    if trade_date < week_starts[0][1]:
        return 'pre-season'
    
    # In-season: assign to latest week whose start date has passed
    for i in range(len(week_starts) - 1):
        current_week, current_start = week_starts[i]
        next_week, next_start = week_starts[i + 1]

        if current_start <= trade_date < next_start:
            return f'{current_week}'

    # After last week
    if trade_date >= week_starts[-1][1]:
        return 'offseason'  # or 'Week 14/15' if you prefer
    
    return 'unknown'

# Apply the function
all_trades['week'] = all_trades.apply(classify_week, axis=1)

# %%
all_trades.tail()
# Out:
#           date receiving_owner giving_owner ro_picks_received ro_picks_gave  \
# 147 2025-10-21            Luis        Bryan          [2027_2]            []
# 148 2025-11-01             Gio      Brigido          [2026_4]            []
# 149 2025-11-08         Brigido         Luis                []      [2026_2]
# 150 2025-11-20             Gio        Jacky          [2027_3]            []
# 151 2025-11-20            Jose        Bryan          [2026_3]            []
#
#     go_picks_received     go_picks_gave  season week
# 147                []          [2027_2]    2025    7
# 148                []          [2026_4]    2025    9
# 149          [2026_2]                []    2025   10
# 150                []          [2027_3]    2025   12
# 151                []  [2026_3, 2026_3]    2025   12

# %%
all_trades.to_parquet('../../Data/2023_2025_pick_trades.parquet')

# %%
all_trades[all_trades['season'] == 2025]
# Out:
#           date receiving_owner giving_owner         ro_picks_received  \
# 116 2025-01-14             Gio        Bryan  [2027_2, 2027_1, 2026_2]
# 117 2025-02-01            Jose      Devonte                  [2025_2]
# 118 2025-02-02            Jose         Luis                  [2027_1]
# 119 2025-02-02         Devonte       Marvin                  [2025_2]
# 120 2025-02-02             Gio         Luis                        []
# 121 2025-02-07         Devonte        Bryan                        []
# 122 2025-02-09            Jose         Luis                  [2025_2]
# 123 2025-02-15         Devonte        Jacky                        []
# 124 2025-02-17           Daryl         Luis                  [2026_2]
# 125 2025-03-12         Brigido         Lalo  [2025_1, 2025_1, 2026_2]
# 126 2025-03-20             Gio      Brigido                        []
# 127 2025-03-31         Brigido       Marvin                        []
# ...
